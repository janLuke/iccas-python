# %%
# %load_ext autoreload
# %autoreload 2

import locale 

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import ipywidgets as widgets
from IPython.display import display

import iccas as ic
import util

# %matplotlib inline
plt.style.use('seaborn')
mpl.rcParams.update({
    'axes.titlesize': 16,
    'axes.titley': 1.05,
    'axes.labelsize': 14,
})

locale.setlocale(locale.LC_ALL, 'Italian');

data = ic.get()

# %% [markdown]
# ## Dati inconsistenti
#
# Dato che l'ISS riporta il **numero di casi e decessi totali a partire dall'inizio dell'epidemia**,
# le serie temporali dovrebbero essere non decrescenti per ogni fascia d'età.
# Tuttavia, non lo sono. Per esempio, la tabella dei decessi sotto mostra come alcune
# serie temporali vadano su per poi riscendere di valore.

# %%
d = data.deaths.loc['2020-05':]
d['Totale'] = d.sum(axis=1)
(d.drop(columns='unknown').style
     .background_gradient()
     .set_caption("Decessi dall'inizio della pandemia")
)
# Out:
# <style  type="text/css" >
# #T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col4,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col5,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col6,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col7,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col8,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col9,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row0_col10,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row5_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row6_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row7_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row8_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row9_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row10_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row11_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row12_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row13_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row14_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row15_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row16_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row17_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row18_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row19_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row20_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row21_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row22_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row23_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row24_col1,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row25_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row19_col5{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col3{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col4{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col5{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col6,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col7,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col9,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col10{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row1_col8{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row5_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row6_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row7_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row7_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row8_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row8_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row9_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row9_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row10_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row10_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row11_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row11_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row12_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row12_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row13_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row14_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row15_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row16_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row17_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row18_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row19_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row20_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row21_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row22_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row23_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row24_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row25_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row26_col0{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row24_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row26_col4{
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col5{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col4{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col5{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col6{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col7{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col8{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col9,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col7{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row2_col10{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col6,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col7,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row5_col4{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col4{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col6{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col8{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col9,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col5{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row3_col10{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col0,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row25_col6{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row5_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row6_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row17_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row18_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row19_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row20_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row21_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row22_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row23_col2,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row27_col2{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col3,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col8,#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row5_col5{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_1d4d82c4_30d4_11eb_b61f_a8a15930a2a5row4_col4{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_1d4d

# %% [markdown]
# La tabella sotto mostra le date in cui il numero di nuovi decessi dall'ultimo rilevamento sono negativi per almeno una fascia d'età. In un caso (ultima riga), si riporta che un numero negativo di nuovi decessi in totale.

# %%
def highlight_negatives(val):
    if val < 0:
        return 'background-color: red; color: white;'

def show_decreasing_values(df):
    deltas = df.drop(columns='unknown') \
               .diff(1).dropna() \
               .astype(int)
    has_miracles = (deltas < 0).any(axis=1)
    with_negative_deltas = deltas[has_miracles].copy()
    with_negative_deltas['Totale'] = with_negative_deltas.sum(1)
    return with_negative_deltas.style.applymap(highlight_negatives)


show_decreasing_values(data.deaths).set_caption(
    "Bollettini nei quali il numero di nuovi decessi (rispetto al bollettino precedente) è negativo.")
# Out:
# <style  type="text/css" >
# #T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col2,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col0,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col5,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col4,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col2,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col4,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col5,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col6,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col7,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col8,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col9,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col10,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row5_col2,#T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row6_col2{
#             background-color:  red;
#              color:  white;
#         }</style><table id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5" ><caption>Bollettini nei quali il numero di nuovi decessi (rispetto al bollettino precedente) è negativo.</caption><thead>    <tr>        <th class="index_name level0" >age_group</th>        <th class="col_heading level0 col0" >0-9</th>        <th class="col_heading level0 col1" >10-19</th>        <th class="col_heading level0 col2" >20-29</th>        <th class="col_heading level0 col3" >30-39</th>        <th class="col_heading level0 col4" >40-49</th>        <th class="col_heading level0 col5" >50-59</th>        <th class="col_heading level0 col6" >60-69</th>        <th class="col_heading level0 col7" >70-79</th>        <th class="col_heading level0 col8" >80-89</th>        <th class="col_heading level0 col9" >>=90</th>        <th class="col_heading level0 col10" >Totale</th>    </tr>    <tr>        <th class="index_name level0" >date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5level0_row0" class="row_heading level0 row0" >2020-05-26 16:00:00</th>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col2" class="data row0 col2" >-2</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col4" class="data row0 col4" >5</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col5" class="data row0 col5" >8</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col6" class="data row0 col6" >40</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col7" class="data row0 col7" >115</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col8" class="data row0 col8" >289</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col9" class="data row0 col9" >203</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row0_col10" class="data row0 col10" >659</td>
#             </tr>
#             <tr>
#                         <th id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5level0_row1" class="row_heading level0 row1" >2020-06-09 15:00:00</th>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col0" class="data row1 col0" >-1</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col5" class="data row1 col5" >10</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col6" class="data row1 col6" >35</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col7" class="data row1 col7" >83</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col8" class="data row1 col8" >194</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col9" class="data row1 col9" >147</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row1_col10" class="data row1 col10" >472</td>
#             </tr>
#             <tr>
#                         <th id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5level0_row2" class="row_heading level0 row2" >2020-07-21 11:00:00</th>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col1" class="data row2 col1" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col4" class="data row2 col4" >3</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col5" class="data row2 col5" >-2</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col6" class="data row2 col6" >2</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col7" class="data row2 col7" >21</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col8" class="data row2 col8" >15</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col9" class="data row2 col9" >21</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row2_col10" class="data row2 col10" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5level0_row3" class="row_heading level0 row3" >2020-08-25 14:00:00</th>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col4" class="data row3 col4" >-1</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col5" class="data row3 col5" >12</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col6" class="data row3 col6" >12</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col7" class="data row3 col7" >67</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col8" class="data row3 col8" >111</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col9" class="data row3 col9" >66</td>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row3_col10" class="data row3 col10" >268</td>
#             </tr>
#             <tr>
#                         <th id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5level0_row4" class="row_heading level0 row4" >2020-09-08 11:00:00</th>
#                         <td id="T_1d5c832c_30d4_11eb_98c1_a8a15930a2a5row4_col0" class="d

# %% [markdown]
# Non conosco la ragione di tali inconsistenze, ma posso presumere che alcuni dei decessi inizialmente attribuiti al coronavirus sono poi stati imputati ad altra causa.

# %% [markdown]
# ## Correzione dei dati
#
# ### Algoritmo di correzione della monoticità
#
# Nel correggere i dati, assumerò che i dati siano tanto più affidabili quanto più recenti. Ciò significa che andrò a considerare "invalidi" i valori all'interno di una serie che sono maggiori di almeno uno dei valori successivi.
#
#
# 1. Per ogni serie numerica, settare a `NaN` tutti i valori all'interno della serie che sono maggiori di almeno un valore successivo.
# 2. Interpolare i valori "nullificati" al punto uno; io ho usato il metodo di interpolazione PCHIP.
# 3. Affinché la somma dei valori disaggregati per sesso siano minori o uguali dei corrispondenti totali,
#    calcolare la serie dei totali come massimo tra la serie dei casi totali corretta (al punto 2) e la somma delle serie
#    relative ai due sessi (corrette).

# %% [markdown]
# ### Visualizzazione delle correzioni

# %%
def show_corrections(data, variable='deaths', age_group=5, period=None):
    period = slice(*period) if period else slice(data.index[0], data.index[-1])
    
    if isinstance(age_group, int):
        age_group = data.columns.unique(1)[8]
        
    nullified = ic.processing.nullify_local_bumps(data)
    fixed = ic.fix_monotonicity(data)

    (data[variable]
        .loc[period, age_group]
        .plot(style='--X', color='orangered', label='Originale', figsize=(13, 7)))

    (fixed[variable]
        .loc[period, age_group]
        .plot(style='--o', color='green', label='Correzione'))

    (nullified[variable]
        .loc[period, age_group]
        .plot(style='-o', linewidth=2, color='darkblue', label='Tratto comune'))
    
    var_label = 'casi' if variable == 'cases' else 'deceduti'
    plt.title(f'Esempio di correzione della monotonicità [{var_label}, {age_group if age_group != "unknown" else "?"} anni]')
    plt.legend()
    plt.xlabel('')


util.with_interaction(
    show_corrections,
    controls=dict(
        data      = widgets.fixed(data),
        variable  = util.variable_form_field(value='deaths'),
        age_group = ('Età', widgets.Dropdown(value='80-89', options=data.columns.unique(1))), 
        period    = util.period_form_field(data.index, value=('2020-06', None))
    )
)
# Out:
# VBox(children=(GridBox(children=(Label(value='Casi / Decessi:', layout=Layout(display='flex', justify_content=…

# %%
d = ic.fix_monotonicity(data).deaths
d['Totale'] = d.sum(1)
d.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col3,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col4,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col5,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col6,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col7,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col8,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col9,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col11,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row3_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row3_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row3_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row4_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row4_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row4_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row4_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row5_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row5_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row6_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row6_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row7_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row8_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row9_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row10_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row10_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row11_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row11_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row12_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row12_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row13_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row14_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row14_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row15_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row15_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row16_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row17_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row17_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row18_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row18_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row19_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row19_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row20_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row20_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row21_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row22_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row22_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row23_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row23_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row24_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row24_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row25_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row25_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row26_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row26_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row27_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row27_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row28_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row28_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row29_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row30_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row31_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row32_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row33_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row34_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row35_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row36_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row37_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row0_col10,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row14_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row15_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row16_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row17_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row18_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row19_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row20_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row21_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row21_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row22_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row22_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row23_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row23_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row24_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row24_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row25_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row25_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row26_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row26_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row27_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row27_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row28_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row28_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row29_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row29_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row30_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row30_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row31_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row31_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row32_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row32_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row33_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row33_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row34_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row34_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row35_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row35_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row36_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row36_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row37_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row37_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col0,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col1,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col2,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col3,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col4,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col5,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col6,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col7,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col8,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col9,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row38_col11{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col3{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col4,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col5,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col8,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col11{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col6{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col7{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row1_col9{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col3{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col4{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col5,#T_519ead0d_2812_11eb_91db_a8a15930a2a5row3_col9{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_519ead0d_2812_11eb_91db_a8a15930a2a5row2_col6{
#             background-color:  #f6eff7;
#             color

# %% [markdown]
# ## Verifiche

# %%
fixed = ic.fix_monotonicity(data)

# %%
ic.checks.is_non_decreasing(fixed)
# Out:
# True

# %%
ic.checks.totals_not_less_than_sum_of_sexes(fixed, 'cases')
# Out:
# True

# %%
ic.checks.totals_not_less_than_sum_of_sexes(fixed, 'deaths')
# Out:
# True

# %% [markdown]
# ## Comparazione con i dati della protezione civile

# %%
from pathlib import Path
import requests


def download(url, dirpath='.', fname=None):
    fname = fname or Path(url).name
    path = Path(dirpath, fname)
    resp = requests.get(url)
    with open(path, 'wb') as f:
        f.write(resp.content)
    return path

dpc_url = 'https://github.com/pcm-dpc/COVID-19/raw/master/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv'
dpc_path = download(dpc_url, dirpath='data')

# %%
iss = ic.resample(ic.get(), hour=18)
iss_fixed = ic.fix_monotonicity(iss)
dpc = pd.read_csv(dpc_path, parse_dates=['data'], index_col='data')
dpc.tail()
# Out:
#                     stato  ricoverati_con_sintomi  terapia_intensiva  \
# data
# 2020-11-21 17:00:00   ITA                   34063               3758
# 2020-11-22 17:00:00   ITA                   34279               3801
# 2020-11-23 17:00:00   ITA                   34697               3810
# 2020-11-24 17:00:00   ITA                   34577               3816
# 2020-11-25 17:00:00   ITA                   34313               3848
#
#                      totale_ospedalizzati  isolamento_domiciliare  \
# data
# 2020-11-21 17:00:00                 37821                  753925
# 2020-11-22 17:00:00                 38080                  767867
# 2020-11-23 17:00:00                 38507                  758342
# 2020-11-24 17:00:00                 38393                  759993
# 2020-11-25 17:00:00                 38161                  753536
#
#                      totale_positivi  variazione_totale_positivi  \
# data
# 2020-11-21 17:00:00           791746                       14570
# 2020-11-22 17:00:00           805947                       14201
# 2020-11-23 17:00:00           796849                       -9098
# 2020-11-24 17:00:00           798386                        1537
# 2020-11-25 17:00:00           791697                       -6689
#
#                      nuovi_positivi  dimessi_guariti  deceduti  \
# data
# 2020-11-21 17:00:00           34767           539524     49261
# 2020-11-22 17:00:00           28337           553098     49823
# 2020-11-23 17:00:00           22930           584493     50453
# 2020-11-24 17:00:00           23232           605330     51306
# 2020-11-25 17:00:00           25853           637149     52028
#
#                      casi_da_sospetto_diagnostico  casi_da_screening  \
# data
# 2020-11-21 17:00:00                      844177.0           536354.0
# 2020-11-22 17:00:00                      858957.0           549911.0
# 2020-11-23 17:00:00                      870461.0           561334.0
# 2020-11-24 17:00:00                      882238.0           572784.0
# 2020-11-25 17:00:00                      896155.0           584719.0
#
#                      totale_casi   tamponi  casi_testati note
# data
# 2020-11-21 17:00:00      1380531  20199829    12120989.0  NaN
# 2020-11-22 17:00:00      1408868  20388576    12225850.0  NaN
# 2020-11-23 17:00:00      1431795  20537521    12303705.0  NaN
# 2020-11-24 17:00:00      1455022  20726180    12398952.0  NaN
# 2020-11-25 17:00:00      1480874  20956187    12513129.0  NaN

# %%
def compare_with_dpc_data(variable='cases', period=None):
    min_start = iss.index[0].strftime('%Y-%m-%d')
    if period is None:
        period = slice(min_start, None)
    elif isinstance(period, tuple):
        period = slice(*period)
    elif not isinstance(slice):
        raise TypeError('period')
    
    if variable == 'cases':
        dpc_data = dpc.loc[period, 'totale_casi']
    else:
        dpc_data = dpc.loc[period, 'deceduti']
    
    dpc_data.plot(figsize=(13,8), label='Dati Protezione Civile', color='blue')
    iss.loc[period, variable].sum(1).plot(label='Dati ISS originali', color='red')
    iss_fixed.loc[period, variable].sum(1).plot(label='Dati ISS corretti', color='green')
    label = 'Casi' if variable == 'cases' else 'deaths'
    plt.title(f"{variable} dall'inizio della pandemia")
    plt.xlabel('')
    util.legend()
    
    
util.with_interaction(
    compare_with_dpc_data,
    controls=dict(
        variable = util.variable_form_field('deaths'),
        period = util.period_form_field(iss.index)
    )
)
# Out:
# VBox(children=(GridBox(children=(Label(value='Casi / Decessi:', layout=Layout(display='flex', justify_content=…
